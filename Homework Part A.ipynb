# %%
import pandas as pd

# %%
pd. __version__
# Out:
# '1.3.4'

# %%
engine = create_engine('postgresql://postgres:Deep$123@localhost:5432/postgres')

# %%
df_iter = pd.read_csv('green_tripdata_2019-01.csv', iterator=True, chunksize=100000)

# %%
df = next(df_iter)

# %%
df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)

# %%
df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)

# %%
df
# Out:
#        VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0             2  2018-12-21 15:17:29   2018-12-21 15:18:57                  N
# 1             2  2019-01-01 00:10:16   2019-01-01 00:16:32                  N
# 2             2  2019-01-01 00:27:11   2019-01-01 00:31:38                  N
# 3             2  2019-01-01 00:46:20   2019-01-01 01:04:54                  N
# 4             2  2019-01-01 00:19:06   2019-01-01 00:39:43                  N
# ...         ...                  ...                   ...                ...
# 99995         2  2019-01-06 09:56:09   2019-01-06 10:01:30                  N
# 99996         2  2019-01-06 09:12:49   2019-01-06 09:52:38                  N
# 99997         2  2019-01-06 09:02:06   2019-01-06 09:37:42                  N
# 99998         2  2019-01-06 09:55:01   2019-01-06 10:04:34                  N
# 99999         2  2019-01-06 09:59:04   2019-01-06 10:24:33                  N
#
# ...

# %%
df.head(n=0).to_sql(name ='yellow_taxi_data_new', con=engine, if_exists='replace')

# %%
# %time df.to_sql(name ='yellow_taxi_data_new', con=engine, if_exists='append')
# Out:
# Wall time: 10.6 s

# %%
from time import time

# %%
while True:
    t_start = time()
    
    df =next(df_iter)
    
    df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
    df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)
    
    df.to_sql(name ='yellow_taxi_data_new', con=engine, if_exists='append')
    
    t_end = time()
    
    print('inserted another chunk..., took %.3f second' % (t_end - t_start))
# Out:
# inserted another chunk..., took 10.813 second
# inserted another chunk..., took 11.214 second
# inserted another chunk..., took 12.033 second
# inserted another chunk..., took 10.865 second
# inserted another chunk..., took 10.752 second
# inserted another chunk..., took 3.409 second
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_33572/537122126.py in <module>
#       2     t_start = time()
#       3
# ----> 4     df =next(df_iter)
#       5
#       6     df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers\readers.py in __next__(self)
#    1022     def __next__(self):
#    1023         try:
# -> 1024             return self.get_chunk()
#    1025         except StopIteration:
#    1026             self.close()
#
# ...

# %%
df1 = pd.read_csv('taxi+_zone_lookup.csv')

# %%
df1
# Out:
#      LocationID        Borough                     Zone service_zone
# 0             1            EWR           Newark Airport          EWR
# 1             2         Queens              Jamaica Bay    Boro Zone
# 2             3          Bronx  Allerton/Pelham Gardens    Boro Zone
# 3             4      Manhattan            Alphabet City  Yellow Zone
# 4             5  Staten Island            Arden Heights    Boro Zone
# ..          ...            ...                      ...          ...
# 260         261      Manhattan       World Trade Center  Yellow Zone
# 261         262      Manhattan           Yorkville East  Yellow Zone
# 262         263      Manhattan           Yorkville West  Yellow Zone
# 263         264        Unknown                       NV          NaN
# 264         265        Unknown                      NaN          NaN
#
# [265 rows x 4 columns]

# %%
df1.head(n=0).to_sql(name ='zones_new', con=engine, if_exists='replace')

# %%
df1.to_sql(name ='zones_new', con=engine, if_exists='append')
